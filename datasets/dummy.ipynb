# %%
from icecream import ic
from torch_frame.data import DataLoader
from ibm_transactions_for_aml import IBMTransactionsAML
dataset = IBMTransactionsAML('/mnt/data/ibm-transactions-for-anti-money-laundering-aml/dummy.csv', pretrain=True)
dataset.materialize()
is_classification = dataset.task_type.is_classification
ic(is_classification)
ic(dataset.col_stats['Payment Currency'])
ic(dataset.col_stats['Amount Paid'])
ic(dataset.df.head(5))

train_dataset, val_dataset, test_dataset = dataset.split()
train_tensor_frame = train_dataset.tensor_frame
train_loader = DataLoader(train_tensor_frame, batch_size=32, shuffle=True)
example = next(iter(train_loader))
ic(example)
ic(example.get_col_feat('Payment Currency'))
ic(example.get_col_feat('Amount Paid'))
# Out:
# ic| is_classification: True
# ic| dataset.col_stats['Payment Currency']: {<StatType.COUNT: 'COUNT'>: (['US Dollar',
#                                                                          'Euro',
#                                                                          'Swiss Franc',
#                                                                          'Yuan',
#                                                                          'Shekel',
#                                                                          'Rupee',
#                                                                          'UK Pound',
#                                                                          'Yen',
#                                                                          'Ruble',
#                                                                          'Bitcoin',
#                                                                          'Canadian Dollar',
#                                                                          'Australian Dollar',
#                                                                          'Mexican Peso',
#                                                                          'Saudi Riyal',
#                                                                          'Brazil Real'],
#                                                                         [332969,
#                                                                          205544,
#                                                                          41190,
#                                                                          37450,
#                                                                          33782,
#                                                                          33675,
#                                                                          30517,
#                                                                          27418,
#                                                                          27113,
#                                                                          24956,
#                                                                          23922,
#                                                                          23749,
#                                                                          19613,
#                                                                          15080,
#                                                                          12257])}
# ic| dataset.col_stats['Amount Paid']: {<StatType.MEAN: 'MEAN'>: 6189337.74734506,
#                                        <StatType.STD: 'STD'>: 494123880.2233011,
#                                        <StatType.QUANTILES: 'QUANTILES'>: [1e-06,
#                                                                            99.29,
#                                                                            1934.87,
#                                                                            24848.08,
#                                                                            284383178291.41]}
# ic| dataset.df.head(5):    Timestamp From Bank    From ID To Bank      To ID  Amount Received  \
#                         0       1200      B_10  8000EBD30     NaN  8000EBD30          3697.34
#                         1       1200       NaN  8000F4580     B_1  8000F5340             0.01
#                         2          0    B_3209  8000F4670  B_3209  8000F4670         14675.57
#                         3        120      B_12  8000F5030    B_12        NaN          2806.97
#                         4        360      B_10  8000F5200    B_10  8000F5200              NaN
#
#                           Receiving Currency  Amount Paid Payment Currency Payment Format  \
#                         0          US Dollar      3697.34        US Dollar   Reinvestment
#                         1          US Dollar         0.01        US Dollar         Cheque
#                         2          US Dollar     14675.57              NaN   Reinvestment
#                         3          US Dollar      2806.97        US Dollar   Reinvestment
#                         4          US Dollar     36682.97        US Dollar   Reinvestment
#
#                           Is Laundering            MASK  split
#                         0             0       (B_10, 3)      0
#                         1             0     (B_3208, 1)      0
#                         2             0  (US Dollar, 8)      0
#                         3             0  (8000F5030, 4)      0
#                         4             0   (36682.97, 5)      0
# ic| example: TensorFrame(
#                num_cols=10,
#                num_rows=32,
#                categorical (7): ['From Bank', 'From ID', 'Payment Currency', 'Payment Format', 'Receiving Currency', 'To Bank', 'To ID'],
#                timestamp (1): ['Timestamp'],
#                numerical (2): ['Amount Paid', 'Amount Received'],
#                has_target=True,
#                device='cpu',
#              )
# ic| example.get_col_feat('Payment Currency'): tensor([[ 0],
#                                                       [-1],
#                                                       [ 0],
#                                                       [ 9],
#                                                       [ 1],
#                                                       [ 2],
#                                                       [ 0],
#                                                       [ 1],
#                                                       [ 1],
#                                                       [ 0],
#                                                       [ 1],
#                                                       [ 4],
#                                                       [ 1],
#                                                       [ 0],
#                                                       [ 1],
#                                                       [-1],
#                                                       [-1],
#                                                       [ 9],
#                                                       [ 0],
#                                                       [ 3],
#                                                       [ 2],
#                                                       [ 1],
#                                                       [12],
#                                                       [ 9],
#                                                       [ 0],
#                                                       [ 9],
#                                                       [ 0],
#                                                       [ 3],
#                                                       [ 0],
#                                                       [ 1],
#                                                       [11],
#                                                       [ 0]])
# ic| example.get_col_feat('Amount Paid'): tensor([[4.6021e+03],
#                                                  [6.7120e+01],
#                                                  [3.4155e+03],
#                                                  [9.6391e-01],
#                                                  [1.4890e+01],
#                                                  [2.5816e+04],
#                                                  [2.2380e+02],
#                                                  [7.6330e+03],
#                                                  [1.4180e+01],
#                                                  [2.3879e+03],
#                                                  [4.4123e+03],
#                                                  [5.0163e+03],
#                                                  [       nan],
#                                                  [       nan],
#                                                  [1.4390e+04],
#                                                  [1.2566e+04],
#                                                  [8.4150e+01],
#                                                  [2.3346e+01],
#                                                  [1.2530e+01],
#                                                  [1.1389e+04],
#                                                  [7.4619e+03],
#                                                  [5.7600e+00],
#                                                  [       nan],
#                                                  [3.8277e+01],
#                                                  [5.7335e+02],
#                                                  [2.6461e-01],
#                                                  [4.7370e+01],
#                                                  [3.4556e+05],
#                                                  [1.2262e+02],
#                                                  [8.1717e+03],
#                                                  [8.6661e+02],
#                                                  [1.1739e+04]])
# tensor([[4.6021e+03],
#         [6.7120e+01],
#         [3.4155e+03],
#         [9.6391e-01],
#         [1.4890e+01],
#         [2.5816e+04],
#         [2.2380e+02],
#         [7.6330e+03],
#         [1.4180e+01],
#         [2.3879e+03],
#         [4.4123e+03],
#         [5.0163e+03],
#         [       nan],
#         [       nan],
#         [1.4390e+04],
#         [1.2566e+04],
#         [8.4150e+01],
#         [2.3346e+01],
#         [1.2530e+01],
#         [1.1389e+04],
#         [7.4619e+03],
#         [5.7600e+00],
#         [       nan],
#         [3.8277e+01],
#         [5.7335e+02],
#         [2.6461e-01],
#         [4.7370e+01],
#         [3.4556e+05],
#         [1.2262e+02],
#         [8.1717e+03],
#         [8.6661e+02],
#         [1.1739e+04]])

# %%
ic(example.y)
ic(len(train_tensor_frame.y))
ic(train_tensor_frame.y[0])
# Out:
# ic| example.y: tensor([     1,      2, 373156,  92706, 221834, 334810,    184,      8, 211319,
#                         43351,  94748,     45,   4183, 283819, 322664,      2,      2, 369397,
#                             1,     51, 314558,   1389, 353304,  28036,      0, 320065,      1,
#                         80395,      1,      3, 345472,   1475])
# ic| len(train_tensor_frame.y): 999487
# ic| train_tensor_frame.y[0]: tensor(44)
# tensor(44)
